# %%
# %pip install Faker
# Out:
# Collecting Faker
#   Downloading faker-37.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /opt/anaconda3/lib/python3.12/site-packages (from Faker) (2023.3)
# Downloading faker-37.4.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 231.2 kB/s eta 0:00:0000:0100:01
# Installing collected packages: Faker
# Successfully installed Faker-37.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from faker import Faker
import numpy as np
import random
from datetime import datetime, timedelta

# %%
book_path = 'Books_df.csv'

data_book = pd.read_csv(book_path)

data_book.head(20)
# Out:
#     Unnamed: 0                                              Title  \
# 0            0              The Complete Novel of Sherlock Holmes
# 1            1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2            2                                    The Kite Runner
# 3            3  Greenlights: Raucous stories and outlaw wisdom...
# 4            4  The Science of Storytelling: Why Stories Make ...
# 5            5  Fantastic Beasts and Where to Find Them: The O...
# 6            6  Fantastic Beasts: The Crimes of Grindelwald - ...
# 7            7  Desperately Seeking Shah Rukh : India's Lonely...
# 8            8  Save the Cat!: The Last Book on Screenwriting ...
# 9            9                                         Screenplay
# 10          10                                            One Day
# 11          11                   SACH KAHUN TOH: AN AUTOBIOGRAPHY
# 12          12                          A PRINCESS REMEMBERS (PB)
# 13          13                               The Anatomy of Story
# 14          14                  Studio Ghibli: The Complete Works
# 15          15  Story: Style, Structure, Substance, and the Pr...
# 16          16  Greenlights: Raucous stories and outlaw wisdom...
# 17          17                                          BRUCE LEE
# 18          18                               JOURNEYS IN THE WILD
# 19          19        Speaking Of Films (The Penguin Ray Library)
#
#                     Author                Main Genre           Sub Genre  \
# 0       Arthur Conan Doyle  Arts, Film & Photography  Cinema & Broadcast
# 1          Stephen Hawking  Arts, Film & Photography  Cinema & Broadcast
# 2          Khaled Hosseini  Arts, Film & Photography  Cinema & Broadcast
# 3      Matthew McConaughey  Arts, Film & Photography  Cinema & Broadcast
# 4               Will Storr  Arts, Film & Photography  Cinema & Broadcast
# 5             J.K. Rowling  Arts, Film & Photography  Cinema & Broadcast
# 6             J.K. Rowling  Arts, Film & Photography  Cinema & Broadcast
# 7    Shrayana Bhattacharya  Arts, Film & Photography  Cinema & Broadcast
# 8             Blake Snyder  Arts, Film & Photography  Cinema & Broadcast
# 9                Syd Field  Arts, Film & Photography  Cinema & Broadcast
# 10          David Nicholls  Arts, Film & Photography  Cinema & Broadcast
# 11             NEENA GUPTA  Arts, Film & Photography  Cinema & Broadcast
# 12        Maharani Gayatri  Arts, Film & Photography  Cinema & Broadcast
# 13              John Truby  Arts, Film & Photography  Cinema & Broadcast
# 14           Studio Ghibli  Arts, Film & Photography  Cinema & Broadcast
# 15            Robert McKee  Arts, Film & Photography  Cinema & Broadcast
# 16     Matthew McConaughey  Arts, Film & Photography  Cinema & Broadcast
# 17           Matthew Polly  Arts, Film & Photography  Cinema & Broadcast
# 18  Sir David Attenborough  Arts, Film & Photography  Cinema & Broadcast
# 19            Satyajit Ray  Arts, Film & Photography  Cinema & Broadcast
#
#                  Type      Price  Rating  No. of People rated  \
# 0           Paperback    ₹169.00     4.4              19923.0
# 1           Paperback     ₹99.00     4.5               7686.0
# 2      Kindle Edition    ₹175.75     4.6              50016.0
# 3           Paperback    ₹389.00     4.6              32040.0
# 4           Paperback    ₹348.16     4.5               1707.0
# 5      Kindle Edition    ₹313.95     4.5              15122.0
# 6      Kindle Edition    ₹313.95     4.6              10152.0
# 7           Paperback    ₹348.16     4.5                539.0
# 8           Paperback    ₹850.00     4.5               7060.0
# 9           Paperback    ₹644.52     4.5               3216.0
# 10  Audible Audiobook    ₹892.00     4.2              10550.0
# 11          Hardcover    ₹361.00     4.4               1558.0
# 12          Paperback    ₹572.00     4.5                719.0
# 13          Paperback    ₹479.00     4.6               2871.0
# 14          Hardcover  ₹2,132.78     4.8                226.0
# 15          Hardcover  ₹2,612.00     4.7               2653.0
# 16     Kindle Edition    ₹371.70     4.6              32040.0
# 17          Paperback    ₹424.00     4.7                915.0
# 18          Paperback    ₹438.00     4.6                389.0
# 19          Paperback    ₹207.00     4.6                311.0
#
#                                                  URLs
# 0   https://www.amazon.in/Complete-Novels-Sherlock...
# 1   https://www.amazon.in/Black-Holes-Lectures-Ste...
# 2   https://www.amazon.in/Kite-Runner-Khaled-Hosse...
# 3   https://www.amazon.in/Greenlights-Raucous-stor...
# 4   https://www.amazon.in/Science-Storytelling-Wil...
# 5   https://www.amazon.in/Fantastic-Beasts-Where-F...
# 6   https://www.amazon.in/Fantastic-Beasts-Grindel...
# 7   https://www.amazon.in/Desperately-Seeking-Shah...
# 8   https://www.amazon.in/Save-Cat-Last-Screenwrit...
# 9   https://www.amazon.in/Screenplay-Foundations-S...
# 10  https://www.amazon.in/One-Day/dp/B079P515NK/re...
# 11  https://www.amazon.in/SACH-KAHUN-AUTOBIOGRAPHY...
# 12  https://www.amazon.in/Princess-Remembers-Mahar...
# 13  https://www.amazon.in/Anatomy-Story-Becoming-M...
# 14  https://www.amazon.in/Studio-Ghibli-Complete-W...
# 15  https://www.amazon.in/Story-Structure-Substanc...
# 16  https://www.amazon.in/Greenlights-Raucous-stor...
# 17  https://www.amazon.in/Bruce-Lee-Life-Matthew-P...
# 18  https://www.amazon.in/JOURNEYS-WILD-Sir-David-...
# 19  https://www.amazon.in/Speaking-Films-Satyajit-...

# %% [markdown]
# # Sorted columns to be used

# %%
book_sorted = data_book[['Title','Author','Main Genre']]
book_sorted.head(20)
# Out:
#                                                 Title                  Author  \
# 0               The Complete Novel of Sherlock Holmes      Arthur Conan Doyle
# 1   Black Holes (L) : The Reith Lectures [Paperbac...         Stephen Hawking
# 2                                     The Kite Runner         Khaled Hosseini
# 3   Greenlights: Raucous stories and outlaw wisdom...     Matthew McConaughey
# 4   The Science of Storytelling: Why Stories Make ...              Will Storr
# 5   Fantastic Beasts and Where to Find Them: The O...            J.K. Rowling
# 6   Fantastic Beasts: The Crimes of Grindelwald - ...            J.K. Rowling
# 7   Desperately Seeking Shah Rukh : India's Lonely...   Shrayana Bhattacharya
# 8   Save the Cat!: The Last Book on Screenwriting ...            Blake Snyder
# 9                                          Screenplay               Syd Field
# 10                                            One Day          David Nicholls
# 11                   SACH KAHUN TOH: AN AUTOBIOGRAPHY             NEENA GUPTA
# 12                          A PRINCESS REMEMBERS (PB)        Maharani Gayatri
# 13                               The Anatomy of Story              John Truby
# 14                  Studio Ghibli: The Complete Works           Studio Ghibli
# 15  Story: Style, Structure, Substance, and the Pr...            Robert McKee
# 16  Greenlights: Raucous stories and outlaw wisdom...     Matthew McConaughey
# 17                                          BRUCE LEE           Matthew Polly
# 18                               JOURNEYS IN THE WILD  Sir David Attenborough
# 19        Speaking Of Films (The Penguin Ray Library)            Satyajit Ray
#
#                   Main Genre
# 0   Arts, Film & Photography
# 1   Arts, Film & Photography
# 2   Arts, Film & Photography
# 3   Arts, Film & Photography
# 4   Arts, Film & Photography
# 5   Arts, Film & Photography
# 6   Arts, Film & Photography
# 7   Arts, Film & Photography
# 8   Arts, Film & Photography
# 9   Arts, Film & Photography
# 10  Arts, Film & Photography
# 11  Arts, Film & Photography
# 12  Arts, Film & Photography
# 13  Arts, Film & Photography
# 14  Arts, Film & Photography
# 15  Arts, Film & Photography
# 16  Arts, Film & Photography
# 17  Arts, Film & Photography
# 18  Arts, Film & Photography
# 19  Arts, Film & Photography

# %%
book_sorted = book_sorted.rename(columns = {'Title': 'title', 'Author': 'author','Main Genre': 'category_name'})

# %%
book_sorted['book_id'] = range(1, len(book_sorted) + 1)
book_sorted.head()
# Out:
#                                                title               author  \
# 0              The Complete Novel of Sherlock Holmes   Arthur Conan Doyle
# 1  Black Holes (L) : The Reith Lectures [Paperbac...      Stephen Hawking
# 2                                    The Kite Runner      Khaled Hosseini
# 3  Greenlights: Raucous stories and outlaw wisdom...  Matthew McConaughey
# 4  The Science of Storytelling: Why Stories Make ...           Will Storr
#
#               category_name  book_id
# 0  Arts, Film & Photography        1
# 1  Arts, Film & Photography        2
# 2  Arts, Film & Photography        3
# 3  Arts, Film & Photography        4
# 4  Arts, Film & Photography        5

# %%
book_sorted = book_sorted[['book_id','title','author','category_name']]
book_sorted.head(20)
# Out:
#     book_id                                              title  \
# 0         1              The Complete Novel of Sherlock Holmes
# 1         2  Black Holes (L) : The Reith Lectures [Paperbac...
# 2         3                                    The Kite Runner
# 3         4  Greenlights: Raucous stories and outlaw wisdom...
# 4         5  The Science of Storytelling: Why Stories Make ...
# 5         6  Fantastic Beasts and Where to Find Them: The O...
# 6         7  Fantastic Beasts: The Crimes of Grindelwald - ...
# 7         8  Desperately Seeking Shah Rukh : India's Lonely...
# 8         9  Save the Cat!: The Last Book on Screenwriting ...
# 9        10                                         Screenplay
# 10       11                                            One Day
# 11       12                   SACH KAHUN TOH: AN AUTOBIOGRAPHY
# 12       13                          A PRINCESS REMEMBERS (PB)
# 13       14                               The Anatomy of Story
# 14       15                  Studio Ghibli: The Complete Works
# 15       16  Story: Style, Structure, Substance, and the Pr...
# 16       17  Greenlights: Raucous stories and outlaw wisdom...
# 17       18                                          BRUCE LEE
# 18       19                               JOURNEYS IN THE WILD
# 19       20        Speaking Of Films (The Penguin Ray Library)
#
#                     author             category_name
# 0       Arthur Conan Doyle  Arts, Film & Photography
# 1          Stephen Hawking  Arts, Film & Photography
# 2          Khaled Hosseini  Arts, Film & Photography
# 3      Matthew McConaughey  Arts, Film & Photography
# 4               Will Storr  Arts, Film & Photography
# 5             J.K. Rowling  Arts, Film & Photography
# 6             J.K. Rowling  Arts, Film & Photography
# 7    Shrayana Bhattacharya  Arts, Film & Photography
# 8             Blake Snyder  Arts, Film & Photography
# 9                Syd Field  Arts, Film & Photography
# 10          David Nicholls  Arts, Film & Photography
# 11             NEENA GUPTA  Arts, Film & Photography
# 12        Maharani Gayatri  Arts, Film & Photography
# 13              John Truby  Arts, Film & Photography
# 14           Studio Ghibli  Arts, Film & Photography
# 15            Robert McKee  Arts, Film & Photography
# 16     Matthew McConaughey  Arts, Film & Photography
# 17           Matthew Polly  Arts, Film & Photography
# 18  Sir David Attenborough  Arts, Film & Photography
# 19            Satyajit Ray  Arts, Film & Photography

# %% [markdown]
# # Category Table

# %%
df_category = pd.DataFrame(book_sorted['category'].unique(), columns = ['category_name'])
df_category.head()
# Out:
#                           category_name
# 0              Arts, Film & Photography
# 1  Biographies, Diaries & True Accounts
# 2                  Business & Economics
# 3                      Children's Books
# 4                       Comics & Mangas

# %%
df_category['category_id'] = range(1, len(df_category) + 1)
df_category.head()
# Out:
#                           category_name  category_id
# 0              Arts, Film & Photography            1
# 1  Biographies, Diaries & True Accounts            2
# 2                  Business & Economics            3
# 3                      Children's Books            4
# 4                       Comics & Mangas            5

# %%
df_category = df_category[['category_id', 'category_name']]
df_category.head()
# Out:
#    category_id                         category_name
# 0            1              Arts, Film & Photography
# 1            2  Biographies, Diaries & True Accounts
# 2            3                  Business & Economics
# 3            4                      Children's Books
# 4            5                       Comics & Mangas

# %% [markdown]
# category table done

# %% [markdown]
# # Book Table

# %%
df_book = pd.merge(book_sorted, df_category, how = 'inner', on = 'category_name')
df_book.head()
# Out:
#    book_id                                              title  \
# 0        1              The Complete Novel of Sherlock Holmes
# 1        2  Black Holes (L) : The Reith Lectures [Paperbac...
# 2        3                                    The Kite Runner
# 3        4  Greenlights: Raucous stories and outlaw wisdom...
# 4        5  The Science of Storytelling: Why Stories Make ...
#
#                 author             category_name  category_id
# 0   Arthur Conan Doyle  Arts, Film & Photography            1
# 1      Stephen Hawking  Arts, Film & Photography            1
# 2      Khaled Hosseini  Arts, Film & Photography            1
# 3  Matthew McConaughey  Arts, Film & Photography            1
# 4           Will Storr  Arts, Film & Photography            1

# %%
df_book = df_book[['book_id','title','author','category_id']]
df_book.head()
# Out:
#    book_id                                              title  \
# 0        1              The Complete Novel of Sherlock Holmes
# 1        2  Black Holes (L) : The Reith Lectures [Paperbac...
# 2        3                                    The Kite Runner
# 3        4  Greenlights: Raucous stories and outlaw wisdom...
# 4        5  The Science of Storytelling: Why Stories Make ...
#
#                 author  category_id
# 0   Arthur Conan Doyle            1
# 1      Stephen Hawking            1
# 2      Khaled Hosseini            1
# 3  Matthew McConaughey            1
# 4           Will Storr            1

# %% [markdown]
# book table done

# %% [markdown]
# # Library Table

# %%
fake = Faker('id_ID')

num_libraries = 30
libraries = []

for library_id in range(1, num_libraries + 1):
    library_name = f"Perpustakaan {fake.city()}"
    if np.random.rand() > 0.7:  
        library_name = f"Perpustakaan Umum {fake.street_name()}"
    
    libraries.append({
        'library_id': library_id,
        'name': library_name,
        'address': fake.address().replace("\n", ", "),
        'phone': fake.phone_number()
    })


df_libraries = pd.DataFrame(libraries)

df_libraries.head(10)
# Out:
#    library_id                                    name  \
# 0           1       Perpustakaan Umum Gg. Pacuan Kuda
# 1           2  Perpustakaan Umum Gang R.E Martadinata
# 2           3              Perpustakaan Pangkalpinang
# 3           4                     Perpustakaan Bitung
# 4           5         Perpustakaan Umum Jl. Kebonjati
# 5           6                    Perpustakaan Ternate
# 6           7                     Perpustakaan Padang
# 7           8                    Perpustakaan Sibolga
# 8           9                  Perpustakaan Gorontalo
# 9          10                     Perpustakaan Kediri
#
#                                              address                phone
# 0       Gg. Sentot Alibasa No. 426, Blitar, AC 40182       (044) 274-9901
# 1        Gang Asia Afrika No. 12, Salatiga, RI 32979     +62-114-899-1641
# 2              Jalan Laswi No. 94, Cilegon, SR 35956   +62 (624) 247-3119
# 3          Gg. Sentot Alibasa No. 6, Dumai, JB 57738       (070) 174 9028
# 4         Gg. Veteran No. 1, Pangkalpinang, MA 81961  +62 (0079) 923 1511
# 5  Jalan Stasiun Wonokromo No. 681, Bukittinggi, ...      (0351) 114-5013
# 6      Jl. Yos Sudarso No. 029, Purwokerto, SS 37722         081 443 0565
# 7       Jalan Suryakencana No. 7, Bengkulu, SG 04576         081 609 3623
# 8  Jalan Cikapayang No. 3, Cilegon, Nusa Tenggara...   +62 (146) 846 0184
# 9   Jl. Cikutra Barat No. 7, Pangkalpinang, KR 58064     +62-017-749-2981

# %% [markdown]
# # Library_book Table

# %%
num_data_lib_book = 200
lib_book = []

for books in range(1, num_data_lib_book + 1):
    lib_book.append({
        'library_id': random.choice(df_libraries['library_id']),
        'book_id': random.choice(df_book['book_id']),
        'quantity': fake.random_int(1, 10, 1)
    })


df_library_book = pd.DataFrame(lib_book)

df_library_book.head(10)
# Out:
#    library_id  book_id  quantity
# 0           1      476         5
# 1           7     1309         5
# 2           7      444         9
# 3          27     3207        10
# 4          21     7697         3
# 5          11     3742         4
# 6          11     2614         4
# 7          15     6801         9
# 8          26     5007         8
# 9          16     5537         3

# %% [markdown]
# # User Table

# %%
num_users = 500  
start_date = datetime.now() - timedelta(days=365) 

users = []
for user_id in range(1, num_users + 1):

    fullname = fake.name()
    email = f"{fullname.split()[0].lower()}.{fake.random_number(digits=3)}@{fake.domain_name()}"
    
    created_at = fake.date_time_between(start_date=start_date, end_date="now")
    
    users.append({
        'user_id': user_id,
        'email': email,
        'password': fake.password(length=12),  
        'fullname': fullname,
        'created_at': created_at
    })

# Create DataFrame
df_users = pd.DataFrame(users)

# Convert created_at to proper datetime format
df_users['created_at'] = pd.to_datetime(df_users['created_at'])

df_users.head(10)
# Out:
#    user_id                 email      password                   fullname  \
# 0        1     lili.594@pt.go.id  )4gO4pYa^86z               Lili Winarno
# 1        2   aurora.161@cv.go.id  8sL(NWYc$9%f             Aurora Maulana
# 2        3    dalimin.256@pd.net  !tcc19ZiZwef            Dalimin Dabukke
# 3        4   siska.469@pd.mil.id  #bDRQFjOsX2U        Siska Kusumo, S.Ked
# 4        5      gatot.309@cv.com  Tj%7fzK9&2HA              Gatot Maryadi
# 5        6  ismail.401@pt.net.id  Lu3#3VNvQ$tH  Ismail Maheswara, S.I.Kom
# 6        7  sadina.132@pt.biz.id  p9M)q0r^vb7B            Sadina Sitompul
# 7        8       drg..772@pt.org  SjN3VYlvk(8E   drg. Puti Nugroho, S.Kom
# 8        9     aurora.140@pt.edu  T#6w+K*dvrPZ          Aurora Firmansyah
# 9       10      gilda.724@pt.com  *fT^TiGHb2TV               Gilda Natsir
#
#                   created_at
# 0 2024-09-06 01:32:19.045890
# 1 2025-01-31 18:57:31.612774
# 2 2024-12-12 12:39:48.638564
# 3 2024-10-05 13:10:45.601202
# 4 2025-03-17 04:52:04.900110
# 5 2024-12-07 07:07:19.837381
# 6 2025-04-16 15:43:32.589882
# 7 2024-11-19 10:48:10.501260
# 8 2024-09-08 12:05:16.030314
# 9 2025-06-04 09:45:33.927936

# %% [markdown]
# df_users done

# %% [markdown]
# # Loan Tables

# %%
fake = Faker('id_ID')

num_loans = 1000
start_date = datetime.now() - timedelta(days=365) 

user_created_map = dict(zip(df_users['user_id'], df_users['created_at']))

loans = []
for loan_id in range(1, num_loans + 1):

    user_id = random.choice(df_users['user_id'])
    library_id = random.choice(df_libraries['library_id'])
    book_id = random.choice(df_book['book_id'])
    
    user_created = user_created_map[user_id]
    
    loan_date = fake.date_time_between(
        start_date=max(user_created, start_date),
        end_date='now'
    )
    
    due_date = loan_date + timedelta(days=14)
    
    status = random.choices(
        ['Active', 'Returned', 'Cancelled'],
        weights=[0.3, 0.65, 0.05],  
        k=1
    )[0]
    
    if status == 'returned':
        if random.random() < 0.7:
            return_date = fake.date_time_between(
                start_date=loan_date, 
                end_date=due_date
            )
        else:
            return_date = fake.date_time_between(
                start_date=due_date,
                end_date=due_date + timedelta(days=random.randint(1, 60))
            )
    elif status == 'cancelled':

        return_date = fake.date_time_between(
            start_date=loan_date,
            end_date=loan_date + timedelta(days=1))
        
    else:  # active
        # Active loans haven't been returned yet
        return_date = None
        
        # Ensure due date is in future for some active loans
        if random.random() < 0.7:  # 70% of active loans should be current
            # Make loan_date recent enough that due_date is in future
            loan_date = fake.date_time_between(
                start_date=datetime.now() - timedelta(days=13),
                end_date='now'
            )
            due_date = loan_date + timedelta(days=14)

    loans.append({
        'loan_id': loan_id,
        'status': status,
        'user_id': user_id,
        'library_id': library_id,
        'book_id': book_id,
        'loan_date': loan_date,
        'due_date': due_date,
        'return_date': return_date
    })

df_loan = pd.DataFrame(loans)

df_loan = df_loan[['loan_id', 'status', 'user_id', 'library_id', 'book_id', 
                     'loan_date', 'due_date', 'return_date']]

df_loan.sample(10)
# Out:
#      loan_id     status  user_id  library_id  book_id  \
# 907      908     Active      496          26     3961
# 912      913   Returned      472           8      541
# 443      444   Returned      160          23     5518
# 942      943  Cancelled      252          19     5692
# 54        55     Active      235          25     3769
# 276      277     Active      285          22     7588
# 739      740   Returned      301          10      953
# 364      365  Cancelled      216          15     3490
# 551      552   Returned      456           8     4475
# 126      127   Returned      358           3     7398
#
#                      loan_date                   due_date return_date
# 907 2024-11-21 17:17:50.126285 2024-12-05 17:17:50.126285        None
# 912 2025-06-27 13:32:17.686675 2025-07-11 13:32:17.686675        None
# 443 2025-06-24 01:09:20.672224 2025-07-08 01:09:20.672224        None
# 942 2025-06-15 14:53:03.989542 2025-06-29 14:53:03.989542        None
# 54  2025-06-16 18:26:09.222963 2025-06-30 18:26:09.222963        None
# 276 2025-06-16 05:02:08.985251 2025-06-30 05:02:08.985251        None
# 739 2025-06-17 19:44:18.340244 2025-07-01 19:44:18.340244        None
# 364 2025-06-25 08:39:53.825937 2025-07-09 08:39:53.825937        None
# 551 2025-06-16 16:05:40.376633 2025-06-30 16:05:40.376633        None
# 126 2025-06-15 17:23:49.267106 2025-06-29 17:23:49.267106        None

# %% [markdown]
# df_loans done

# %% [markdown]
# # Holds Table

# %%
# Initialize Faker
fake = Faker('id_ID')

# Assuming you have these DataFrames already:
# df_users, df_libraries, df_books

# Parameters
num_holds = 3000  # Number of holds to generate
start_date = datetime.now() - timedelta(days=365) 

# Generate hold data
holds = []
for hold_id in range(1, num_holds + 1):
    # Randomly select entities
    user_id = random.choice(df_users['user_id'])
    library_id = random.choice(df_libraries['library_id'])
    book_id = random.choice(df_book['book_id'])
    
    # Generate hold date (within past year)
    hold_date = fake.date_time_between(start_date=start_date, end_date='now')
    
    # Expiration date is always 7 days after hold date
    expiration_date = hold_date + timedelta(days=7)
    
    # Determine status based on time logic
    current_time = datetime.now()
    if expiration_date > current_time:
        # Still within hold period
        status = random.choices(
            ['Active', 'Cancelled'], 
            weights=[0.85, 0.15],  # 85% active, 15% cancelled
            k=1
        )[0]
    else:
        # Hold period has expired
        status = random.choices(
            ['Expired', 'Fulfilled', 'Cancelled'],
            weights=[0.7, 0.25, 0.05],  # 70% expired, 25% fulfilled, 5% cancelled
            k=1
        )[0]
    
    holds.append({
        'hold_id': hold_id,
        'user_id': user_id,
        'library_id': library_id,
        'book_id': book_id,
        'hold_date': hold_date,
        'expiration_date': expiration_date,
        'status': status
    })

# Create DataFrame
df_holds = pd.DataFrame(holds)

# Reorder columns
df_holds = df_holds[['hold_id', 'status', 'library_id', 'user_id', 'book_id', 
                      'hold_date', 'expiration_date']]

df_holds.head(10)
# Out:
#    hold_id     status  library_id  user_id  book_id  \
# 0        1    Expired          25      156     5946
# 1        2    Expired           4      234     6282
# 2        3    Expired           1      380     4428
# 3        4    Expired          16      328     5225
# 4        5    Expired          27      295     4577
# 5        6    Expired           1       84     4330
# 6        7    Expired           8      320     7268
# 7        8    Expired          26      354     6560
# 8        9  Fulfilled          30       88      505
# 9       10  Cancelled          11      163     5487
#
#                    hold_date            expiration_date
# 0 2025-04-06 19:30:47.492622 2025-04-13 19:30:47.492622
# 1 2024-08-16 19:11:47.655095 2024-08-23 19:11:47.655095
# 2 2024-12-25 12:55:58.143771 2025-01-01 12:55:58.143771
# 3 2024-12-24 01:37:06.814279 2024-12-31 01:37:06.814279
# 4 2025-06-17 23:13:50.567868 2025-06-24 23:13:50.567868
# 5 2024-09-15 09:06:44.120911 2024-09-22 09:06:44.120911
# 6 2024-12-17 07:15:22.042021 2024-12-24 07:15:22.042021
# 7 2025-05-04 21:42:07.309312 2025-05-11 21:42:07.309312
# 8 2024-11-14 05:37:11.639642 2024-11-21 05:37:11.639642
# 9 2024-07-17 10:24:11.252127 2024-07-24 10:24:11.252127

# %% [markdown]
# df_holds done

# %% [markdown]
# # Exporting df created to CSV

# %%
df_book.to_csv('df_book.csv', index=False)
df_category.to_csv('df_categories.csv', index=False)
df_libraries.to_csv('df_libraries.csv', index=False)
df_library_book.to_csv('df_library_book.csv', index=False)
df_loan.to_csv('df_loan.csv', index=False)
df_holds.to_csv('df_holds.csv', index=False)
df_users.to_csv('df_users.csv', index=False)
